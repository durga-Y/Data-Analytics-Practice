# %% [markdown]
# ### List Task

# %%
### Q1

# %%
L = [10, 20, 30, 40, 50]
L[1:5:2]
# Out:
# [20, 40]

# %%
### Q2

# %%
L= [1,2,3,4,10,9,8,4]
L[5: :1]
# Out:
# [9, 8, 4]

# %%
L= [1,2,3,4,5,6,7,8,9] # Not tought yet 
print(" The maximum of list:",max(L))
print("The minimum of the list:", min(L))
# Out:
#  The maximum of list: 9
# The minimum of the list: 1

# %%
L = ['a','b','c','d','e']
L.reverse()
L
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
L = ["dbp","dby","dbp","dbp","dby"]
L.count("dbp")
# Out:
# 3

# %%
L=['yellow', 'black', 'red', 'orange', 'pink']
L[0] = 'pink'
L[4] = 'yellow'
L
# Out:
# ['pink', 'black', 'red', 'orange', 'yellow']

# %%
L=[25,30,[26,27,28,"hello"],32,38]
L[2][3]
# Out:
# 'hello'

# %%
L[2][1] = 43

# %%
L
# Out:
# [25, 30, [26, 43, 28, 'hello'], 32, 38]

# %%
L.insert(3,'True')

# %%
L
# Out:
# [25, 30, [26, 43, 28, 'hello'], 'True', 32, 38]

# %%
L1 = [1,2,3,4]
L2 = [5,6,7,8]
L3 = L2+L1

print("single sorted list:",sorted(L3))
# Out:
# single sorted list: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
#Q14

# %%
L1 = [1,3,4,5,6]
L2 = [5,6,7,8,9]
L1.extend(L2)
L1
# Out:
# [1, 3, 4, 5, 6, 5, 6, 7, 8, 9]

# %%
L = [4,5,1,2,9,7,10,8]
a = sum(L)
b = a/len(L)
print("Sum of the given list :", a)
print("Average of the given list:",b)
# Out:
# Sum of the given list : 46
# Average of the given list: 5.75

# %%
#Q16

# %%
L = [(2,5),(1,2),(4,4),(2,3),(2,1)]
L.sort()
L
# Out:
# [(1, 2), (2, 1), (2, 3), (2, 5), (4, 4)]

# %%
#Q17

# %%
a = int(input("Eneter a first number :" ))
b = int(input("Enter a Second Number :" ))
c=a-b        
print("Diffrence between two given number:", c)
# Out:
# Eneter a first number : 5
# Enter a Second Number : 2
# Diffrence between two given number: 3

# %%
#Q18

# %%
a = [1,2,3,4]
b = [9,8,7,6]
a=b.copy()
print(a)
print(b)
# Out:
# [9, 8, 7, 6]
# [9, 8, 7, 6]

# %%
#Q19

# %%
mylist = [23,24,25,26,27,28,29,30]
mylist.pop(0)
mylist.pop(4)
mylist.pop(5)
print(mylist)
# Out:
# [24, 25, 26, 27, 29]

# %%
#Q20

# %%
a = [1,2,3,4]
b = [9,8,7,6]
a.append(b)
print(a)
# Out:
# [1, 2, 3, 4, [9, 8, 7, 6]]

# %%
#21

# %%
lst = [2,4,2,4,6,7,4,2,6,]
lst.count(2)
# Out:
# 3

# %%
#22 need to ceross check with sir

# %%
lst = [2,4,2,4,6,7,4,2,6,]                   
unique_values = list(set(lst))
print(unique_values)
# Out:
# [2, 4, 6, 7]

# %%
#24

# %%
lst = [23,24,25,26,27]
lst.reverse()
lst
# Out:
# [27, 26, 25, 24, 23]

# %%
#25
