# %% [markdown]
# #### Dictionaries Task

# %%
#1

# %%
d = {'durga':24, 'bhanu':25,}
d
# Out:
# {'durga': 24, 'bhanu': 25}

# %%
#2

# %%
d['Raji']= 27
d
# Out:
# {'durga': 24, 'bhanu': 25, 'Raji': 27}

# %%
#3

# %%
d = {'durga': 24, 'bhanu': 25, 'Raji': 27}
d.pop('durga')
d
# Out:
# {'bhanu': 25, 'Raji': 27}

# %%
#4

# %%
d = {'durga': 24, 'bhanu': 25, 'Raji': 27}
d.items()
d
# Out:
# {'durga': 24, 'bhanu': 25, 'Raji': 27}

# %%
#5

# %%
person = {'name': 'Alia', 'Age': 25, 'city':'New York'}
person.get('Age')
# Out:
# 25

# %%
#Q6 merginf two dictionaries

# %%
d1 = {'durga': 24} 
d2 = {'bhanu': 25}
A = {**d1, **d2}
print(A)
# Out:
# {'durga': 24, 'bhanu': 25}

# %%
#7

# %%
d = {'durga': 24, 'bhanu': 25, 'Raji': 27}
d

# %%
# q8comprehension

# %%
#9

# %%
L = ['Durga', 'DA']
dict([L])
# Out:
# {'Durga': 'DA'}

# %%
#10

# %%
L = [('even',2), ('odd', 3),('negative',-1), ('positive',1)]
dict(L)
# Out:
# {'even': 2, 'odd': 3, 'negative': -1, 'positive': 1}

# %%
#11 Sorting in dictionary

# %%
#12 swap in dictionary

# %%
#13

# %%
d = {'a':2,'b': 4,'c':6, 'd':8}
d.get('b')
# Out:
# 4

# %%
#15

# %%
d = {'durga': 24, 'bhanu': 25, 'Raji': 27}
d.items()
# Out:
# dict_items([('durga', 24), ('bhanu', 25), ('Raji', 27)])

# %%
#15

# %%
d = {'a':2,'b': 4,'c':6, 'd':8}
del d['c']
d
# Out:
# {'a': 2, 'b': 4, 'd': 8}

# %%
#16

# %%
original_dict={'name':'Alice', 'Age':25, 'food':'mutton'}
print(original_dict)
d=original_dict.copy()
d.update({'colour': 'Yellow'})
print(d)
# Out:
# {'name': 'Alice', 'Age': 25, 'food': 'mutton'}
# {'name': 'Alice', 'Age': 25, 'food': 'mutton', 'colour': 'Yellow'}

# %%
#17 sorting 18 maximum 19 minimum topics

# %%
#20

# %%
d={'name':'Alice', 'Age':25, 'city':'wonderland'}
A = d.items()
dict(A)
# Out:
# {'name': 'Alice', 'Age': 25, 'city': 'wonderland'}

# %%
# if else topic 21Q

# %%
#22

# %%
d={'name':'Alice', 'Age':25,}
print(id(d))
A = d.copy()
id(A)
# Out:
# 1899901571584
# 1899901571968

# %%
d={'name':'Alice', 'Age':25,}
A = d.get('name')
print(A)
# Out:
# Alice

# %%
#24 -> reverse topic

# %%
#25 conver dictionary to list of tuple

# %%
d = {'a':1,'b':2}
a =tuple(d)
b = list([a])
b
# Out:
# [('a', 'b')]

# %%
#26Qsort and length

# %%
#27

# %%
d = {'a':{'x':1,'y':2}}
del d['a']['x']
d
# Out:
# {'a': {'y': 2}}

# %%
#28

# %%
d={'a': {'y': 2}}
d.update({'x':1})
d
# Out:
# {'a': {'y': 2}, 'x': 1}

# %%
#29

# %%
d= {'a':1,'b':2,'c':3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
#30

# %%
d= {'a':1,'b':2,'c':3}
d.clear()
d
# Out:
# {}
