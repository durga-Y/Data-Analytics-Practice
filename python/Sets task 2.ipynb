# %%
#10

# %%
l=[1,2,3]
print(set(l))
# Out:
# {1, 2, 3}

# %%
#19

# %%
S1 = [1,2,3,4,5]
S2 = [4,5,6,7,8]
A = set(S2)
B = A.isdisjoint(S1)
print(B)
# Out:
# False

# %%
#18

# %%
l1=[1,5,10,20,40,80]
l2=[6,7,2,0,80,100]
l3=[3,4,1,5,20,30,70,80,120]

A = set(l2)
B = A.intersection(set(l2))
C = B.intersection(set(l3))
print(C)
# Out:
# {80}

# %%
#15

# %%
L = [9,1,1,2,5,5,6,6]

print(set(L))
# Out:
# {1, 2, 5, 6, 9}

# %%
#30

# %%
L1 = [1,2,3,4,5]
L2 = [3,2,4,6,8]
A =set(L1)
print(A)
B = set(L2)
print(B)
# Out:
# {1, 2, 3, 4, 5}
# {2, 3, 4, 6, 8}

# %%
#29

# %%
#28

# %%
s ={10,20,30,40,50}
s.clear()
print(s)
# Out:
# set()

# %%
#25

# %%
s={'a','b','c','d','e'}
A = tuple(s)
print(A)
t =('a','c','b','e','d')
B = set(t)
print(B)
# Out:
# ('e', 'b', 'c', 'd', 'a')
# {'e', 'b', 'c', 'd', 'a'}

# %%
#24

# %%
s = {1,2,3,4,5}
l = [3,4,6]
A = set(l)
s.intersection(A)
# Out:
# {3, 4}

# %%
#23

# %%
L = [1,2,2,3,4,4,5]

# %%
#22

# %%
s = {1,2,3,4}
A = list(s)
A.remove(3)

print(set(A))
# Out:
# {1, 2, 4}

# %%
#20

# %%
A = {1,2,2,4,8}
B = {2,8,6,10,1}
A.symmetric_difference(B)
# Out:
# {4, 6, 10}
