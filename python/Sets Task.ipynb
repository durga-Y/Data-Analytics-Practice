# %% [markdown]
# #### Sets Task

# %%
#Q1

# %%
S = {1,'dby',2.5,(2,3),}   #sets,liss data type not acceptable
print(S)
# Out:
# {(2, 3), 1, 2.5, 'dby'}

# %%
s={1,2,3,4,5}
s.remove(3)
print(s)
# Out:
# {1, 2, 4, 5}

# %%
s1 = {1,2,3,4,5}
s2= {4,5,6,7,8}
ans = s1.union(s2)
print(ans)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1 = {1,2,3,4,5}
s2= {4,5,6,7,8}
ans = s1.symmetric_difference(s2)
print(ans)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
s={1,2,3,4,5}
s.discard(7)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,2}
s2={1,2,3,4}
s1.issuperset(s2)
# Out:
# False

# %%
s1={1,2,3,4}
s2={3,4,5,6}
s1.difference(s2)
# Out:
# {1, 2}

# %%
s={1,2,3,4,5,1,2,5,4,6,7,8}
len(s)
# Out:
# 8

# %%
s1=[1,2,3,4]
set = s1
print(s1)
# Out:
# [1, 2, 3, 4]

# %%
l=[1,2,3]
print(set(l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 l=[1,2,3]
# ----> 2 print(set(l))
#
# TypeError: 'list' object is not callable

# %%
s={5,2,8,1,4}
a = max(s)
print("Maximum Value:",a)
s={5,2,8,1,4}
b= min(s)
print("Minimum Value:",b)
# Out:
# Maximum Value: 8
# Minimum Value: 1

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}
A = s1.intersection(s2)
print(A)
# Out:
# {4, 5}

# %%
#14

# %%
s1 ={1,2}
s2 = {2,3}
s3 = {3,4}
A = s1.union(s2)
B = A.union(s3)
print(B)
# Out:
# {1, 2, 3, 4}

# %%
L1 = [1,2,3,4,5]
L2 = [3,2,4,6,8]
L3 = L1+L2
print(L3)
A =set(L3)
# Out:
# [1, 2, 3, 4, 5, 3, 2, 4, 6, 8]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 5
#       3 L3 = L1+L2
#       4 print(L3)
# ----> 5 A =set(L3)
#
# TypeError: 'list' object is not callable
