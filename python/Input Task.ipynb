# %% [markdown]
# # Input Task
# ### Q.1

# %%
a = int(float(input(" Enter the first number :")))
b = int(float(input(" Enter the second number :")))     
print(" the sum of given numbers :", a+b)
# Out:
#  Enter the first number : 123.890
#  Enter the second number : 123
#  the sum of given numbers : 246

# %% [markdown]
# ### Q.2

# %%
d= float(input("enter the float number:"))
print(d)
# Out:
# enter the float number: 345.6
# 345.6

# %% [markdown]
# ### Q3

# %%
Age = (int(input("Enter Your Age: ")))
print(" More", 100 - Age, "years left to reach 100", "!")
# Out:
# Enter Your Age:  25
#  More 75 years left to reach 100 !

# %% [markdown]
# ### Q4

# %%
Name1 = str(input(" Enter Your First Name :"))
Name2 = str(input(" Enter Your Second Name :"))
print (" Here Is your Full Name :", Name1, "" + Name2, "!")
# Out:
#  Enter Your First Name : Durga
#  Enter Your Second Name : Bhavani
#  Here Is your Full Name : Durga Bhavani !

# %% [markdown]
# ### Q5

# %%
r = float(input("Enter the radius:"))
print(" Aria Of a cercle :", 3.14*r*r)
# Out:
# Enter the radius: 3
#  Aria Of a cercle : 28.259999999999998

# %% [markdown]
# ### Q6

# %%
Num = int(input("Enter a Number:"))
print("Your number multiplied number with 2 is:", 2 * Num)    #taking input with defailt is string
# Out:
# Enter a Number: 5
# Your number multiplied number with 2 is: 10

# %% [markdown]
# ### Q7

# %%
x, y, z = input()

print( x + y * z)
# Out:
#  3+5*2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 x, y, z = input()
#       3 print( x + y * z)
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# ### Q8

# %%
Str = int(input(" Enter a Number:"))
print(Str + 10)
# Out:
#  Enter a Number: 10
# 20

# %% [markdown]
# ### Q9

# %%
K = int(float(input(" Enter a value :")))
print("int value of given number:", K, "and", "float value of given number:", float(K))
# Out:
#  Enter a value : 7.0
# int value of given number: 7 and float value of given number: 7.0

# %% [markdown]
# ### Q10

# %%
Name = input(" Enter Your Name:")
print("Welcome,", Name, "!")
# Out:
#  Enter Your Name: Durga Yellaram
# Welcome, Durga Yellaram !
