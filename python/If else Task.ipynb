# %%
#1

# %%
l=[1,2,3,2,1]
if l==l[ : :-1] :
    print("it is a palindrome")
else:
    print("it is not a palindrome")
# Out:
# it is a palindrome

# %%
#2

# %%
number = 13

# %%
x=1
while x<=9:
    n = int(input("Enter the mobile number: "))
s = sum(len(n))
print(s)
    

if s==x:
    print("lst sum of the mobile number is :", s)
# Out:
# Enter the mobile number:  8374362841

# %%
x=1
while x<=9:
    n = int(input("Enter the mobile number: "))
s = sum(len(n))
print(s)
    

if s==x:
    print("lst sum of the mobile number is :", s)
# Out:
# Enter the mobile number:  8374362841

# %%
if x<=9:
    n = (input("Enter the mobile number: "))
    s = sum(len((n)))
    
    
    print("lst sum of the mobile number is :", s)
# Out:
# Enter the mobile number:  786534678
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 if x<=9:
#       2     n = (input("Enter the mobile number: "))
# ----> 3     s = sum(len((n)))
#       6     print("lst sum of the mobile number is :", s)
#
# TypeError: 'int' object is not iterable
