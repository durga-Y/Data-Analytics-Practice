# %% [markdown]
# ### int, float, bool Task

# %% [markdown]
# #### Q1

# %%
a=12
b=5
print(a+b)
# Out:
# 17

# %%
#Q2

# %%
x=10
y=3
z=x*y-y
print("the result:", z)
# Out:
# the result: 27

# %%
# Q3

# %%
x = 10
bool(x)
# Out:
# True

# %%
# Q4

# %%
num1=17
num2=4
print("The remainder of ", num1, "divided by", num2, "is", 17/4)
# Out:
# The remainder of  17 divided by 4 is 4.25

# %%
# Q5

# %%
a = 2*3*4
b = a-4
print(" the multiplcation of 2, 3 and 4 and  substracting with 4 is:", b)
# Out:
#  the multiplcation of 2, 3 and 4 and  substracting with 4 is: 20

# %%
# Q6

# %%
# Q7

# %%
a=10
b=25
print("the difference between a and b :", b-a)
# Out:
# the difference between a and b : 15

# %%
num = 99  # given number 
Add = num +1  # added 1 to given number 
print("Result:", Add) # print
# Out:
# Result: 100

# %%
a = 4   # given number 
b = 4*4  # square of given number 
c=b+1  # added 1 to the square number 
print(c)
# Out:
# 17

# %%
#10

# %%
num=[6,10]  
b= 6*10-5
print("result:", b)
# Out:
# result: 55

# %%
#11

# %%
a = 1.234
b = 2.456
print(float(a*b))   #float type
# Out:
# 3.030704

# %%
r = 2.5  # radius 
pi = 3.14 # pi
print(" the area of cercle is :", int(pi*r*r))   # int type
# Out:
#  the area of cercle is : 19

# %%
# 13

# %%
F = 1.234
I = 1000
result = F*I
print("multiplication of float & large int number is", (result))
# Out:
# multiplication of float & large int number is 1234.0

# %%
# 14

# %%
a = 2.5  # float number 
b = 4   # int number 
c=a+b
print(c)
# Out:
# 6.5

# %%
#15

# %%
numbers = [2.5, 3.5, 7.0]
Avrg= sum(numbers) / len(numbers)
print(" Average :", Avrg)
# Out:
#  Average : 4.333333333333333

# %%
#16

# %%
var1 = 5
var2 = 8.0
print("type of 5:", type(var1), "typeof 8.0:", type(var2))
# Out:
# type of 5: <class 'int'> typeof 8.0: <class 'float'>

# %%
#17

# %%
a=2.0
b=4
print(a*b)
# Out:
# 8.0

# %%
#18

# %%
a=5
b=a/2
print("before:",type(a), "After:",type(b))
# Out:
# before: <class 'int'> After: <class 'float'>

# %%
# 19

# %%
x = 20
bool(x)
# Out:
# True

# %%
#20

# %%
x = 0
bool(x)
# Out:
# False
