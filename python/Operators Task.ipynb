# %%
#1

# %%
E = 10+5*3-2
E
# Out:
# 23

# %%
#2

# %%
result= 7+3*2-8/4
result
# Out:
# 11.0

# %%
#3

# %%
i = 10/3     # division              
j = 10//3    # coetient 
print(i)
print(j)
# Out:
# 3.3333333333333335
# 3

# %%
#4

# %%
a = 5 
print( a**3)
# Out:
# 125

# %%
#5

# %%
a = 10%3   # modulo 
print(a)
b = 10//3   # floor division
print(b)
# Out:
# 1
# 3

# %%
#6

# %%
6+3 * (2**3)// 4-5
# Out:
# 7

# %%
#7

# %%
8+2 * 5 **2 -7 //3 # it will first perform floor division
# Out:
# 56

# %%
#8

# %%
16**2  # square root of 16
# Out:
# 256

# %%
#9

# %%
a=0
b = 2
a/b
# Out:
# 0.0

# %%
a//b
# Out:
# 0

# %%
#10

# %%
a = 0.1 + 0.2
a==0.3
# Out:
# False

# %%
#11

# %%
print(5==5)
print(5==6)
# Out:
# True
# False

# %%
#12

# %%
print(5<10>3)
# Out:
# True

# %%
#13

# %%
5=='5'
# Out:
# False

# %%
#14

# %%
2.0 == 2
# Out:
# True

# %%
#15

# %%
# Logical operators -
# NOT --> not true is false and not false is true 
# AND ---> when both operends are true then only overall output will be true 
# OR ---> either one operend true then only overall out put will be true

# %%
print(not True) 
print(not False )
print(5>4 and 2<3)
print(4>1 or 6<4)
# Out:
# False
# True
# True
# True

# %%
#16

# %%
x=5
y=10
print(x<y and y>5)
# Out:
# True

# %%
#17

# %%
5<10 and 10>7 or 3<2
# Out:
# True

# %%
True or False and False
# Out:
# True

# %%
#18

# %%
a=5
b=10
c=15
print((a<b and b<c) or (a>c))
# Out:
# True

# %%
#19 --> identity operators (is , is not ) check two values are indcating to same object or not

# %%
a=10
b=20
print(a is b)
print(b is not a)
# Out:
# False
# True

# %%
#20

# %%
lst1=[1,2,3]
lst2=lst1
lst3=lst1[:]
print(lst1 is lst2)
print(lst1 is lst3)
# Out:
# True
# False

# %%
id(lst1)
# Out:
# 2644132201920

# %%
id(lst2)
# Out:
# 2644132217280

# %%
id(lst3)
# Out:
# 2644125856384

# %%
#21

# %%
str1 = 'hello'
str2 = 'hello'
str1==str2
# Out:
# True

# %%
#22 logical operators cannot give the result only identity operators can give true for given data

# %%
print(str1 is str2)
# Out:
# True

# %%
#23 if we re assign value it will take latest assigned values

# %%
x = [1,2,3]
y=x
x=[4,5,6]
print(x)
# Out:
# [4, 5, 6]

# %%
print(x is y)
# Out:
# False

# %%
#24 Assignment operators used to assign values to the variables

# %%
x = 10

# %%
 x+= 10
print(x)
# Out:
# 38.5

# %%
x-=3
print(x)
# Out:
# 35.5

# %%
x*=2
print(x)
# Out:
# 71.0

# %%
x/=4
print(x)
# Out:
# 17.75

# %%
#25

# %%
a=5
b=10
c=5
a=b=c=20
x=a+b+c

# %%
print(x)
# Out:
# 60

# %%
#26

# %%
x=8
x//=3
print(x)
# Out:
# 2

# %%
#27

# %%
# in, not in ---> are the membership operators used to test wether the value or variable found in sequense of (list,tuple,set,dict)
a = 'Durga'
print('D' in a)
print('A' not in a)
# Out:
# True
# True

# %%
#28

# %%
str_text = "Welcome to python programming!"
print("python" in str_text)
print("java" in str_text)
# Out:
# True
# False

# %%
#29

# %%
list_numbers = [1,2,3,4,5]
print(3 in list_numbers)
print(6 not in list_numbers)
# Out:
# True
# True

# %%
#30

# %%
Fruits= ('Apple', 'banana', 'cherry')
print('banana' in Fruits)
print('Orange' not in Fruits)
# Out:
# True
# True
