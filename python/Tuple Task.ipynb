# %% [markdown]
# ### Tuple Task

# %%
#Q1

# %%
t = (10,20,30,40,50)
a =t[2]
print("The third element of a tuple:", a)
# Out:
# The third element of a tuple: 30

# %%
#Q2

# %%
t = (5,10,15,20,25)
t[2: :1]
# Out:
# (15, 20, 25)

# %%
#3

# %%
a= (1,2,3)
b=(4,5,6)
c=a+b
print(c)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#4

# %%
t=(7,8)

# %%
#5

# %%
t= (5,10,15,20,25,30)
t.index(15)
# Out:
# 2

# %%
#6

# %%
t= (1,2,3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 t= (1,2,3,4,5,6)
# ----> 2 t.index(t)
#
# ValueError: tuple.index(x): x not in tuple

# %%
#7

# %%
t=(10,20,30,40,50)
t.index(50)
# Out:
# 4

# %%
#8

# %%
t=(2,4,2,6,2,8)
t.count(2)
# Out:
# 3

# %%
#10

# %%
t=(10,20,30,40)
t[-1: :-1]
# Out:
# (40, 30, 20, 10)

# %%
t=(15,6,89,34)
max(t)
# Out:
# 89

# %%
t = (12,3,77,44)
min(t)
# Out:
# 3

# %%
#13

# %%
mytuple=(5)

# %%
t1=(100)
t2=(200)
t3=(300)

# %%
#15

# %%
t =(10,20,30,40,50,60)
t[1: :2]
# Out:
# (20, 40, 60)

# %%
#16

# %%
t=(4,6,2,9,1)
a = min(t) 
b= max(t)
print("Max", b,"Min",a)
# Out:
# Max 9 Min 1

# %%
#17

# %%
t=9,8,7
t.add(99)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 t=9,8,7
# ----> 2 t.add(99)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
#18

# %%
a=(1,2)
b=(4,5)
x=(9)
print(a+b)
# Out:
# (1, 2, 4, 5)
