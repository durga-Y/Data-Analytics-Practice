# %% [markdown]
# ### String Task

# %%
#1

# %%
a = input("Enter a string :")
b = a[-1: : -1]
print(" Here is the reversed string:", b)
# Out:
# Enter a string : durga bhavani yellaram
#  Here is the reversed string: maralley inavahb agrud

# %%
#3

# %%
str = ("String with underscores")
str.replace(" " , "_")
# Out:
# 'String_with_underscores'

# %%
#4

# %%
Str = "banana"
Str.count("a")
# Out:
# 3

# %%
#Q5

# %%
s = "it is my string name "
s.index("it")
# Out:
# 0

# %%
#Q6

# %%
s = "OpenAI"
s.upper()
# Out:
# 'OPENAI'

# %%
#8

# %%
s1 =("Hello", "World")
"".join(s1)
# Out:
# 'HelloWorld'

# %%
#Q10

# %%
s=("Programming")
s[3:7]
# Out:
# 'gram'

# %%
#Q12

# %%
S = "Hello_Everyone"
S.replace("Everyone","There")
# Out:
# 'Hello_There'

# %%
#Q13

# %%
Str = "Hello World how are you"
Str.replace(" ","-")
# Out:
# 'Hello-World-how-are-you'

# %%
#Q14

# %%
s = " Messy Text "#----> leading and trailing (starting ending white spaces )
s.strip()
# Out:
# 'Messy Text'

# %%
#Q15

# %%
s = "Hi There"
print(s.startswith("Hi"))
# Out:
# True

# %%
#16

# %%
s = "I am running"
s.endswith("ing")
# Out:
# True

# %%
#17

# %%
s= "welcome to the jungle"  # only first letter of the sentences will be capital letter 
s.capitalize()
# Out:
# 'Welcome to the jungle'

# %%
#18

# %%
s = "I","Love","Coding" #make sentences from list of items 
" ".join(s)
# Out:
# 'I Love Coding'

# %%
#19

# %%
s = "Python Is Fun"
a = s.lower()
a.replace(" ","_")
# Out:
# 'python_is_fun'

# %%
#20

# %%
s = "hello world python"
a = " ".join(s.split()[ : :-1])         # cross check with sir 
print(a)
# Out:
# python world hello

# %%
#21

# %%
s = "good morning world"   # first letter of the each word changes to capital 
s.title()
# Out:
# 'Good Morning World'

# %%
#22

# %%
s.count("world")
# Out:
# 1

# %%
#22

# %%
s = "apple banana apple mango aplle"
s.count("apple")
# Out:
# 2

# %%
#23

# %%
s = "rececar"
if s.startswith("r") and s.endswith("r"):   # Cross check with sir
     print("True")
else:
     print("False")
# Out:
# True

# %%
#24

# %%
s="aXBYcZd"
a =s[2: :2]
print("Even Postions of the string:",a)
# Out:
# Even Postions of the string: Bcd

# %%
#25

# %%
s = "Tomorrow"

# %%
#26

# %%
s = "Tomorrow is holiday"
s.replace(" ","#")
# Out:
# 'Tomorrow#is#holiday'

# %%
s = "he@llo!#wo$rld
# Out:
#   Cell In[150], line 1
#     s = "he@llo!#wo$rld
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#28

# %%
s="mississippi"
s.index('s')
# Out:
# 2

# %%
#29

# %%
s="hello world hello"
a=s.replace("hello"," ")
a.strip()
# Out:
# 'world'

# %%
#30

# %%
s= "hello woRLD"
s.swapcase()
# Out:
# 'HELLO WOrld'
