# %% [markdown]
# ####Tuple & its methods

# %% [markdown]
# ###Tuple

# %%
# tuple is similar to list except it is immutable which means we cannot change the elements elements of a tuple once we assigned 
# when we do not want to change the data over time tuple is preferred data type 
# iterating over the elements of a tuple is faster compares to iterating over a list

# %%
# Empty tuple

# %%
tup1=()     #---> option1
print(tup1)
# Out:
# ()

# %%
tup2 = tuple()
print(tup2)
# Out:
# ()

# %% [markdown]
# ###### Tuple is heterogenous

# %%
t=(1, 2.3,True,"Dby",[2,4])
t
# Out:
# (1, 2.3, True, 'Dby', [2, 4])

# %%
len(t)
# Out:
# 5

# %% [markdown]
# ###### Nested tuple (tuple within the tuple)

# %%
tup=(2.5,"durga", [2,7], (22,33,44))
tup
# Out:
# (2.5, 'durga', [2, 7], (22, 33, 44))

# %%
# tuple indexing
tup[2]

# %%
tup[2][0]
# Out:
# 2

# %%
tup[-1][1]
# Out:
# 33

# %%
# tuple slicing
tup[0:100]
# Out:
# (2.5, 'durga', [2, 7], (22, 33, 44))

# %% [markdown]
# #### tuple methods

# %%
mytuple1=(1,2,3,4,5,4,6,4,7,4,8,4)
mytuple1
# Out:
# (1, 2, 3, 4, 5, 4, 6, 4, 7, 4, 8, 4)

# %%
#tuple.count() -----> number of times item occured in the tuple

# %%
mytuple1.count(4)
# Out:
# 5

# %%
# tuple index----> return the index postion of a tupe items

# %%
mytuple1.index(3)
# Out:
# 2

# %% [markdown]
# #### tuple are immutable (cant replace item in a tuple)

# %%
tup = (1,2,3,4)          #through the typle error
tup[0] =5
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 tup = (1,2,3,4)
# ----> 2 tup[0] =5
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Delete entire tuple

# %%
tup =(1,2,3,4,5)
del tup     # deleting entire tuple object is possible 
print(tup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 tup =(1,2,3,4,5)
#       2 del tup
# ----> 3 print(tup)
#
# NameError: name 'tup' is not defined

# %% [markdown]
# ##### Tuple sorting

# %%
mytuple = (14,3,2,1)
z = tuple(sorted(mytuple))      
print(z)
# Out:
# (1, 2, 3, 14)

# %%
#if we want to modify the tuple more then convert it to list

# %%
t=(14,3,2,1)
print(t)

l=list(t)
print(l)
# Out:
# (14, 3, 2, 1)
# [14, 3, 2, 1]

# %%
# do the modification and again conver back to tuple

# %%
t=(1,2,3,4)
print(t)
print(id(t))

a = list(t)
del a[0]
t=tuple(a)
print(t)
print(id(t))
# Out:
# (1, 2, 3, 4)
# 2724330587296
# (2, 3, 4)
# 2724330611776

# %% [markdown]
# #### interview question

# %%
# Can we add a value in a list within a tuple ?
t=(1,40,60,[20,15,5],80,100)
t[3].insert(0,66)
t[3].append(66)
t[3]
t
# Out:
# (1, 40, 60, [66, 20, 15, 5, 66], 80, 100)

# %%
# can we replace a value in a list within tuple ?
t=(1,40,60,[20,15,5],80,100)
t[3][1] = 55
t
# Out:
# (1, 40, 60, [20, 55, 5], 80, 100)

# %%
# can we remove a value in a list within a tuple?
t=(1,40,60,[20,15,5],80,100)
t[3].remove(20)
t
# Out:
# (1, 40, 60, [15, 5], 80, 100)
